# %%
import pandas as pd
df = pd.read_excel ('/Users/muki/Library/Containers/com.microsoft.Excel/Data/Downloads/Week7_Store_Data_Sample.xlsx')
df
# Out:
#           Order ID Order Date Customer ID      Segment     Region  \
# 0   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 1   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 2   CA-2016-138688 2016-06-12    MO-17950  Байгууллага    Хан-Уул
# 3   US-2015-108966 2015-10-11    JO-15550     Хувь хүн   Баянзүрх
# 4              NaN        NaT    JO-15550     Хувь хүн   Баянзүрх
# ..             ...        ...         ...          ...        ...
# 95  US-2017-109484 2017-11-06    JR-15700          NaN    Хан-Уул
# 96             NaN        NaT         NaN          NaN        NaN
# 97  CA-2017-157833 2017-06-17    BM-11575     Хувь хүн    Хан-Уул
# 98  CA-2016-149223 2016-09-06    CV-12805  Байгууллага  Чингэлтэй
# 99  CA-2016-158568        NaT    DK-12835          NaN  Чингэлтэй
#
#                            Category             Product Name   Price  \
# 0                    Чихэр, печенье       Shokolinsen 250 гр  3300.0
# ...

# %%
df.isnull()
# Out:
#     Order ID  Order Date  Customer ID  Segment  Region  Category  \
# 0      False       False        False    False   False     False
# 1      False       False        False    False   False     False
# 2      False       False        False    False   False     False
# 3      False       False        False    False   False     False
# 4       True        True        False    False   False     False
# ..       ...         ...          ...      ...     ...       ...
# 95     False       False        False     True   False     False
# 96      True        True         True     True    True      True
# 97     False       False        False    False   False     False
# 98     False       False        False    False   False     False
# 99     False        True        False     True   False     False
#
#     Product Name  Price  Quantity  Discount  Sales
# 0          False  False     False      True  False
# 1          False  False     False      True  False
# ...

# %%
df1 = df.fillna(method = 'ffill')
df1
# Out:
#           Order ID Order Date Customer ID      Segment     Region  \
# 0   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 1   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 2   CA-2016-138688 2016-06-12    MO-17950  Байгууллага    Хан-Уул
# 3   US-2015-108966 2015-10-11    JO-15550     Хувь хүн   Баянзүрх
# 4   US-2015-108966 2015-10-11    JO-15550     Хувь хүн   Баянзүрх
# ..             ...        ...         ...          ...        ...
# 95  US-2017-109484 2017-11-06    JR-15700     Хувь хүн    Хан-Уул
# 96  US-2017-109484 2017-11-06    JR-15700     Хувь хүн    Хан-Уул
# 97  CA-2017-157833 2017-06-17    BM-11575     Хувь хүн    Хан-Уул
# 98  CA-2016-149223 2016-09-06    CV-12805  Байгууллага  Чингэлтэй
# 99  CA-2016-158568 2016-09-06    DK-12835  Байгууллага  Чингэлтэй
#
#                            Category             Product Name   Price  \
# 0                    Чихэр, печенье       Shokolinsen 250 гр  3300.0
# ...

# %%
df2 = df.fillna(method = 'bfill')
df2
# Out:
#           Order ID Order Date Customer ID      Segment     Region  \
# 0   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 1   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 2   CA-2016-138688 2016-06-12    MO-17950  Байгууллага    Хан-Уул
# 3   US-2015-108966 2015-10-11    JO-15550     Хувь хүн   Баянзүрх
# 4   US-2015-108966 2015-10-11    JO-15550     Хувь хүн   Баянзүрх
# ..             ...        ...         ...          ...        ...
# 95  US-2017-109484 2017-11-06    JR-15700     Хувь хүн    Хан-Уул
# 96  US-2017-109484 2017-11-06    JR-15700     Хувь хүн    Хан-Уул
# 97  CA-2017-157833 2017-06-17    BM-11575     Хувь хүн    Хан-Уул
# 98  CA-2016-149223 2016-09-06    CV-12805  Байгууллага  Чингэлтэй
# 99  CA-2016-158568 2016-09-06    DK-12835  Байгууллага  Чингэлтэй
#
#                            Category             Product Name   Price  \
# 0                    Чихэр, печенье       Shokolinsen 250 гр  3300.0
# ...

# %%
df3 = df.dropna(how = 'all', axis=1)
df3
# Out:
#           Order ID Order Date Customer ID      Segment     Region  \
# 0   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 1   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 2   CA-2016-138688 2016-06-12    MO-17950  Байгууллага    Хан-Уул
# 3   US-2015-108966 2015-10-11    JO-15550     Хувь хүн   Баянзүрх
# 4   US-2015-108966 2015-10-11    JO-15550     Хувь хүн   Баянзүрх
# ..             ...        ...         ...          ...        ...
# 95  US-2017-109484 2017-11-06    JR-15700     Хувь хүн    Хан-Уул
# 96  US-2017-109484 2017-11-06    JR-15700     Хувь хүн    Хан-Уул
# 97  CA-2017-157833 2017-06-17    BM-11575     Хувь хүн    Хан-Уул
# 98  CA-2016-149223 2016-09-06    CV-12805  Байгууллага  Чингэлтэй
# 99  CA-2016-158568 2016-09-06    DK-12835  Байгууллага  Чингэлтэй
#
#                            Category             Product Name   Price  \
# 0                    Чихэр, печенье       Shokolinsen 250 гр  3300.0
# ...

# %%
df4 = df.dropna(how = 'all', axis=0)
df4
# Out:
#           Order ID Order Date Customer ID      Segment     Region  \
# 0   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 1   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 2   CA-2016-138688 2016-06-12    MO-17950  Байгууллага    Хан-Уул
# 3   US-2015-108966 2015-10-11    JO-15550     Хувь хүн   Баянзүрх
# 4   US-2015-108966 2015-10-11    JO-15550     Хувь хүн   Баянзүрх
# ..             ...        ...         ...          ...        ...
# 95  US-2017-109484 2017-11-06    JR-15700     Хувь хүн    Хан-Уул
# 96  US-2017-109484 2017-11-06    JR-15700     Хувь хүн    Хан-Уул
# 97  CA-2017-157833 2017-06-17    BM-11575     Хувь хүн    Хан-Уул
# 98  CA-2016-149223 2016-09-06    CV-12805  Байгууллага  Чингэлтэй
# 99  CA-2016-158568 2016-09-06    DK-12835  Байгууллага  Чингэлтэй
#
#                            Category             Product Name   Price  \
# 0                    Чихэр, печенье       Shokolinsen 250 гр  3300.0
# ...
