# %%
n = int(input("Garaas oruulsan utga"))
for i in range(1, n+1):
    for j in range(1, i +1):
        i = '*'
        print(i, end ="")
    print()
# Out:
# Garaas oruulsan utga6
# *
# **
# ***
# ****
# *****
# ******

# %%
n = int(input())
for i in range(1, n + 1):
    k = ['*'*i]
    for j in k:
        print(j)
# Out:
# 6
# *
# **
# ***
# ****
# *****
# ******

# %%
import operator
students = {
    'Bat':18,
    'Oyun':22,
    'Dulam':21,
    'Suren':20
}
a = min(students, key = students.get)
x = students[min(students, key = students.get)]
print(a,x)
b = max(students, key = students.get)
y = students[max(students, key = students.get)]
print(b,y)
# Out:
# Bat 18
# Oyun 22

# %%
arr1 = np.arange(1,1000)
n = 0
for i in arr1:
    if i % 3 == 0 or i % 7 == 0:
        n = n + i
print(n)
