# %%
import pandas as pd
import numpy as np

# %%
xl_irts=pd.read_excel('Бие даалт - 1.xlsx', sheet_name='Ирц')
xl_seminar=pd.read_excel('Бие даалт - 1.xlsx', sheet_name='Семинар')
xl_shalgalt=pd.read_excel('Бие даалт - 1.xlsx', sheet_name='Шалгалт')
xl_biydaalt=pd.read_excel('Бие даалт - 1.xlsx', sheet_name='Бие даалт')
xl_humuujil=pd.read_excel('Бие даалт - 1.xlsx', sheet_name='Хүмүүжил хандлага')
xl_nemelt=pd.read_excel('Бие даалт - 1.xlsx', sheet_name='Нэмэлт оноо')
xl_niit=pd.read_excel('Бие даалт - 1.xlsx', sheet_name='Нийт')
xl_irts
# Out:
#     No  Unnamed: 1 Оюутны код       Оюутны нэр 2021-04-11 00:00:00  \
# 0    1         NaN  K17FF1275        Батмөнх.Д                   и
# 1    2         NaN  K19FF1276      Оюунчимэг.Д                   и
# 2    3         NaN  K16FF1277        Гантуяа.Б                   и
# 3    4         NaN  K16FF1278      Энхжаргал.Д                   и
# 4    5         NaN  K19FF1279  Нарантунгалаг.Ц                   и
# 5    6         NaN  K17FF1280     Цэндхорлоо.П                   и
# 6    7         NaN  K16FF1281     Даваацэцэг.М                   и
# 7    8         NaN  K17FF1282       Батцэцэг.Л                   и
# 8    9         NaN  K18FF1283     Адъяатамир.Т                   и
# 9   10         NaN  K18FF1284      Гүнгэрмаа.Н                   и
# 10  11         NaN  K19FF1285      Байгалмаа.Г                   и
# 11  12         NaN  K19FF1286   Тайванжаргал.Ц                   и
# 12  13         NaN  K19FF1287        Батхуяг.Б                   и
# ...

# %%
xl_irts=xl_irts.replace('и',0.3125)
xl_irts=xl_irts.replace('т',0)
xl_irts['Нийт -10']=xl_irts.iloc[:,4:36].sum(axis=1)
xl_irts
# Out:
#     No  Unnamed: 1 Оюутны код       Оюутны нэр  2021-04-11 00:00:00  \
# 0    1         NaN  K17FF1275        Батмөнх.Д               0.3125
# 1    2         NaN  K19FF1276      Оюунчимэг.Д               0.3125
# 2    3         NaN  K16FF1277        Гантуяа.Б               0.3125
# 3    4         NaN  K16FF1278      Энхжаргал.Д               0.3125
# 4    5         NaN  K19FF1279  Нарантунгалаг.Ц               0.3125
# 5    6         NaN  K17FF1280     Цэндхорлоо.П               0.3125
# 6    7         NaN  K16FF1281     Даваацэцэг.М               0.3125
# 7    8         NaN  K17FF1282       Батцэцэг.Л               0.3125
# 8    9         NaN  K18FF1283     Адъяатамир.Т               0.3125
# 9   10         NaN  K18FF1284      Гүнгэрмаа.Н               0.3125
# 10  11         NaN  K19FF1285      Байгалмаа.Г               0.3125
# 11  12         NaN  K19FF1286   Тайванжаргал.Ц               0.3125
# 12  13         NaN  K19FF1287        Батхуяг.Б               0.3125
# ...

# %%
xl_seminar= xl_seminar.replace(1, 25/19)
xl_seminar.fillna(0)
xl_seminar['Нийт -25']=xl_seminar.iloc[:,4:23].sum(axis=1)
xl_seminar
# Out:
#            No  Unnamed: 1 Оюутны код       Оюутны нэр  Seminar1  Seminar2  \
# 0    1.315789         NaN  K17FF1275        Батмөнх.Д  1.315789  1.315789
# 1    2.000000         NaN  K19FF1276      Оюунчимэг.Д  1.315789  1.315789
# 2    3.000000         NaN  K16FF1277        Гантуяа.Б  1.315789  1.315789
# 3    4.000000         NaN  K16FF1278      Энхжаргал.Д  1.315789  1.315789
# 4    5.000000         NaN  K19FF1279  Нарантунгалаг.Ц  1.315789  1.315789
# 5    6.000000         NaN  K17FF1280     Цэндхорлоо.П  1.315789  1.315789
# 6    7.000000         NaN  K16FF1281     Даваацэцэг.М  1.315789  1.315789
# 7    8.000000         NaN  K17FF1282       Батцэцэг.Л  1.315789  1.315789
# 8    9.000000         NaN  K18FF1283     Адъяатамир.Т  1.315789  1.315789
# 9   10.000000         NaN  K18FF1284      Гүнгэрмаа.Н  1.315789  1.315789
# 10  11.000000         NaN  K19FF1285      Байгалмаа.Г  1.315789  1.315789
# 11  12.000000         NaN  K19FF1286   Тайванжаргал.Ц  1.315789  1.315789
# ...
